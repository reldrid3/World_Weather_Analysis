# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import json
import time
import pprint as pp

from citipy import citipy

# Import the API key.
from config import ow_key

# %%
# Create a set of random latitude and longitude combinations.
np.random.seed(100) #Seed to keep data consistent while testing
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Create an empty list to hold the weather data.
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + ow_key
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descr = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather": city_descr})

# If an error is experienced, skip the city.
    except BaseException as e:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nicoya
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | antalaha
# Processing Record 4 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | juneau
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | port blair
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | dunedin
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | vikhorevka
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | lima
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | caravelas
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | wabrzezno
# Processing Record 27 of Set 1 | araouane
# Processing Record 28 of Set 1 | isla
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | yeppoon
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | oksfjord
# Processing Record 34 of Set 1 | san andres
# Processing Record 35 of Set 1 | biograd na moru
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | moussoro
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 1 | rocha
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | muravlenko
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | gao
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | san cristobal
# Processing Record 49 of Set 1 | arandis
# Processing Record 50 of Set 1 | wuzhou
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | karratha
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | lazaro cardenas
# Processing Record 9 of Set 2 | orbetello
# Processing Record 10 of Set 2 | flinders
# Processing Record 11 of Set 2 | kasongo-lunda
# Processing Record 12 of Set 2 | meulaboh
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | bandarbeyla
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 2 | sao francisco de assis
# Processing Record 17 of Set 2 | tupik
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | itoman
# Processing Record 20 of Set 2 | idah
# Processing Record 21 of Set 2 | maldonado
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | grahamstown
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | bardiyah
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | cockburn town
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | arrecife
# Processing Record 30 of Set 2 | saint-augustin
# Processing Record 31 of Set 2 | erzin
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | nelson bay
# Processing Record 34 of Set 2 | el reno
# Processing Record 35 of Set 2 | nadym
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | iguape
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | dibaya
# City not found. Skipping...
# Processing Record 42 of Set 2 | lasa
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | salina
# Processing Record 45 of Set 2 | puerto escondido
# Processing Record 46 of Set 2 | ituiutaba
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | bindura
# Processing Record 49 of Set 2 | poya
# Processing Record 50 of Set 2 | mbandaka
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | qui nhon
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | bonthe
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | ambositra
# Processing Record 11 of Set 3 | namibe
# Processing Record 12 of Set 3 | morant bay
# Processing Record 13 of Set 3 | tunceli
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | pochutla
# Processing Record 17 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 3 | vangaindrano
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | linjiang
# Processing Record 22 of Set 3 | thunder bay
# Processing Record 23 of Set 3 | calama
# Processing Record 24 of Set 3 | marsh harbour
# Processing Record 25 of Set 3 | nantucket
# Processing Record 26 of Set 3 | koboko
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | evensk
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | mayo
# Processing Record 31 of Set 3 | natal
# Processing Record 32 of Set 3 | pilibanga
# Processing Record 33 of Set 3 | nemencine
# Processing Record 34 of Set 3 | mount gambier
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | nador
# Processing Record 40 of Set 3 | akureyri
# Processing Record 41 of Set 3 | pangnirtung
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | ambilobe
# Processing Record 44 of Set 3 | bodden town
# Processing Record 45 of Set 3 | komsomolskiy
# Processing Record 46 of Set 3 | kishi
# Processing Record 47 of Set 3 | tabou
# Processing Record 48 of Set 3 | port macquarie
# Processing Record 49 of Set 3 | necochea
# Processing Record 50 of Set 3 | kavieng
# Processing Record 1 of Set 4 | kishorganj
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | columbus
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | kieta
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | anamur
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | gizo
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | tuatapere
# Processing Record 12 of Set 4 | yumen
# Processing Record 13 of Set 4 | omsukchan
# Processing Record 14 of Set 4 | fortuna
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | zhigansk
# Processing Record 17 of Set 4 | sambava
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | saint-pierre
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | wageningen
# Processing Record 23 of Set 4 | matipo
# Processing Record 24 of Set 4 | agadez
# Processing Record 25 of Set 4 | la ronge
# Processing Record 26 of Set 4 | swift current
# Processing Record 27 of Set 4 | mezinovskiy
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | bathurst
# Processing Record 30 of Set 4 | arlit
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | trairi
# Processing Record 33 of Set 4 | axim
# Processing Record 34 of Set 4 | sobolevo
# Processing Record 35 of Set 4 | synya
# Processing Record 36 of Set 4 | kirakira
# Processing Record 37 of Set 4 | denpasar
# Processing Record 38 of Set 4 | havre-saint-pierre
# Processing Record 39 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 4 | ibajay
# Processing Record 41 of Set 4 | beidao
# Processing Record 42 of Set 4 | el alto
# Processing Record 43 of Set 4 | vanavara
# Processing Record 44 of Set 4 | kaputa
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | taoudenni
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | glowno
# Processing Record 1 of Set 5 | gelemso
# Processing Record 2 of Set 5 | shagonar
# Processing Record 3 of Set 5 | cascas
# Processing Record 4 of Set 5 | hidalgotitlan
# Processing Record 5 of Set 5 | bontang
# Processing Record 6 of Set 5 | constitucion
# Processing Record 7 of Set 5 | jaque
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | poum
# Processing Record 10 of Set 5 | sept-iles
# Processing Record 11 of Set 5 | abasolo
# Processing Record 12 of Set 5 | salym
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | lagoa
# Processing Record 15 of Set 5 | mitu
# Processing Record 16 of Set 5 | ostrovnoy
# Processing Record 17 of Set 5 | wadi maliz
# Processing Record 18 of Set 5 | bahar
# Processing Record 19 of Set 5 | iracoubo
# Processing Record 20 of Set 5 | caraguatatuba
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | kavaratti
# Processing Record 23 of Set 5 | sembe
# Processing Record 24 of Set 5 | bubaque
# Processing Record 25 of Set 5 | shimoda
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | campestre
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | wad madani
# Processing Record 30 of Set 5 | bedesa
# Processing Record 31 of Set 5 | manono
# Processing Record 32 of Set 5 | alugan
# Processing Record 33 of Set 5 | boende
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | wanderlandia
# City not found. Skipping...
# Processing Record 37 of Set 5 | guiyang
# Processing Record 38 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 5 | sayyan
# Processing Record 40 of Set 5 | kerema
# Processing Record 41 of Set 5 | geneva
# Processing Record 42 of Set 5 | zelezna ruda
# Processing Record 43 of Set 5 | roald
# Processing Record 44 of Set 5 | pacasmayo
# Processing Record 45 of Set 5 | itarema
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | vidalia
# Processing Record 48 of Set 5 | fairview
# Processing Record 49 of Set 5 | villa carlos paz
# Processing Record 50 of Set 5 | honningsvag
# Processing Record 1 of Set 6 | prince rupert
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | tocopilla
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | mnogovershinnyy
# Processing Record 7 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 6 | laiyang
# Processing Record 9 of Set 6 | suisun city
# Processing Record 10 of Set 6 | adrar
# Processing Record 11 of Set 6 | camopi
# Processing Record 12 of Set 6 | manokwari
# Processing Record 13 of Set 6 | opochka
# Processing Record 14 of Set 6 | ust-kuyga
# Processing Record 15 of Set 6 | saskylakh
# Processing Record 16 of Set 6 | kiruna
# Processing Record 17 of Set 6 | nome
# Processing Record 18 of Set 6 | bourg-en-bresse
# Processing Record 19 of Set 6 | nemuro
# Processing Record 20 of Set 6 | sibu
# Processing Record 21 of Set 6 | mogadishu
# Processing Record 22 of Set 6 | la libertad
# Processing Record 23 of Set 6 | jibuti
# Processing Record 24 of Set 6 | osmena
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | rio branco
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 6 | pangoa
# Processing Record 30 of Set 6 | hithadhoo
# Processing Record 31 of Set 6 | oistins
# Processing Record 32 of Set 6 | sinnamary
# Processing Record 33 of Set 6 | bredasdorp
# Processing Record 34 of Set 6 | libertador general san martin
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | tarhunah
# City not found. Skipping...
# Processing Record 39 of Set 6 | ybytimi
# City not found. Skipping...
# Processing Record 40 of Set 6 | marfino
# Processing Record 41 of Set 6 | balotra
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | mikumi
# Processing Record 45 of Set 6 | avera
# Processing Record 46 of Set 6 | san jose
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | saint-joseph
# Processing Record 49 of Set 6 | ye
# City not found. Skipping...
# Processing Record 50 of Set 6 | anloga
# Processing Record 1 of Set 7 | clyde river
# Processing Record 2 of Set 7 | tome
# Processing Record 3 of Set 7 | saldanha
# Processing Record 4 of Set 7 | zaragoza
# Processing Record 5 of Set 7 | byron bay
# Processing Record 6 of Set 7 | ust-omchug
# Processing Record 7 of Set 7 | kalach-na-donu
# Processing Record 8 of Set 7 | korla
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | agrafa
# Processing Record 11 of Set 7 | dekernes
# Processing Record 12 of Set 7 | fairbanks
# Processing Record 13 of Set 7 | padang
# Processing Record 14 of Set 7 | mali
# Processing Record 15 of Set 7 | pizhanka
# Processing Record 16 of Set 7 | lubumbashi
# Processing Record 17 of Set 7 | palmer
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | los llanos de aridane
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | alice springs
# Processing Record 22 of Set 7 | alihe
# Processing Record 23 of Set 7 | port hedland
# Processing Record 24 of Set 7 | san policarpo
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | aguas formosas
# Processing Record 27 of Set 7 | udachnyy
# Processing Record 28 of Set 7 | nishihara
# Processing Record 29 of Set 7 | ndele
# Processing Record 30 of Set 7 | cabedelo
# Processing Record 31 of Set 7 | kuminskiy
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | ormara
# Processing Record 34 of Set 7 | kijang
# Processing Record 35 of Set 7 | gudari
# Processing Record 36 of Set 7 | sainte-maxime
# Processing Record 37 of Set 7 | havoysund
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | lebu
# Processing Record 41 of Set 7 | mahenge
# Processing Record 42 of Set 7 | kaka
# Processing Record 43 of Set 7 | soyo
# Processing Record 44 of Set 7 | puerto leguizamo
# Processing Record 45 of Set 7 | manggar
# Processing Record 46 of Set 7 | boshnyakovo
# Processing Record 47 of Set 7 | vostok
# Processing Record 48 of Set 7 | sisimiut
# Processing Record 49 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 7 | leningradskiy
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | puerto ayacucho
# Processing Record 4 of Set 8 | victoria
# Processing Record 5 of Set 8 | kuytun
# Processing Record 6 of Set 8 | margherita di savoia
# Processing Record 7 of Set 8 | seoul
# Processing Record 8 of Set 8 | la macarena
# Processing Record 9 of Set 8 | price
# Processing Record 10 of Set 8 | luwuk
# Processing Record 11 of Set 8 | la orilla
# Processing Record 12 of Set 8 | port lincoln
# Processing Record 13 of Set 8 | mehamn
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | ledyard
# Processing Record 16 of Set 8 | lewistown
# Processing Record 17 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 8 | williamsburg
# Processing Record 19 of Set 8 | tonantins
# Processing Record 20 of Set 8 | dali
# Processing Record 21 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 8 | svetlyy
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | abu kamal
# Processing Record 25 of Set 8 | sitarganj
# Processing Record 26 of Set 8 | marawi
# Processing Record 27 of Set 8 | bambous virieux
# Processing Record 28 of Set 8 | hongjiang
# Processing Record 29 of Set 8 | astara
# Processing Record 30 of Set 8 | toamasina
# Processing Record 31 of Set 8 | sunndalsora
# Processing Record 32 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 8 | te anau
# Processing Record 34 of Set 8 | buraydah
# Processing Record 35 of Set 8 | porto velho
# Processing Record 36 of Set 8 | manitouwadge
# Processing Record 37 of Set 8 | sao francisco de paula
# Processing Record 38 of Set 8 | faro
# Processing Record 39 of Set 8 | darnah
# Processing Record 40 of Set 8 | abidjan
# Processing Record 41 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 8 | cabo san lucas
# Processing Record 43 of Set 8 | ferme-neuve
# Processing Record 44 of Set 8 | boguchany
# Processing Record 45 of Set 8 | jacareacanga
# Processing Record 46 of Set 8 | ambon
# Processing Record 47 of Set 8 | yulara
# Processing Record 48 of Set 8 | jardim
# Processing Record 49 of Set 8 | nikolskoye
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | albion
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | ahuimanu
# Processing Record 4 of Set 9 | stony plain
# Processing Record 5 of Set 9 | bosconia
# Processing Record 6 of Set 9 | sterling
# Processing Record 7 of Set 9 | yilan
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | east london
# Processing Record 11 of Set 9 | ulverstone
# Processing Record 12 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 13 of Set 9 | gulbarga
# Processing Record 14 of Set 9 | dingzhou
# Processing Record 15 of Set 9 | mildura
# Processing Record 16 of Set 9 | charlestown
# Processing Record 17 of Set 9 | gazojak
# Processing Record 18 of Set 9 | shache
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | eureka
# Processing Record 21 of Set 9 | veraval
# Processing Record 22 of Set 9 | rafsanjan
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | mumford
# Processing Record 25 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 9 | aksu
# Processing Record 27 of Set 9 | svetlaya
# Processing Record 28 of Set 9 | sabaudia
# Processing Record 29 of Set 9 | sur
# Processing Record 30 of Set 9 | rogun
# City not found. Skipping...
# Processing Record 31 of Set 9 | omboue
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | leh
# Processing Record 34 of Set 9 | lekoni
# Processing Record 35 of Set 9 | belaya gora
# Processing Record 36 of Set 9 | andselv
# City not found. Skipping...
# Processing Record 37 of Set 9 | okhotsk
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | aleksandrovskiy zavod
# Processing Record 40 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 9 | maragogi
# Processing Record 42 of Set 9 | luba
# Processing Record 43 of Set 9 | merauke
# Processing Record 44 of Set 9 | ordzhonikidze
# Processing Record 45 of Set 9 | celestun
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 48 of Set 9 | mulchen
# Processing Record 49 of Set 9 | nara
# Processing Record 50 of Set 9 | mopipi
# Processing Record 1 of Set 10 | rio gallegos
# Processing Record 2 of Set 10 | kjellerup
# Processing Record 3 of Set 10 | honiara
# Processing Record 4 of Set 10 | boa vista
# Processing Record 5 of Set 10 | ancud
# Processing Record 6 of Set 10 | imeni poliny osipenko
# Processing Record 7 of Set 10 | bambanglipuro
# Processing Record 8 of Set 10 | panguna
# Processing Record 9 of Set 10 | hambantota
# Processing Record 10 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | channel-port aux basques
# Processing Record 12 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 10 | fukue
# Processing Record 14 of Set 10 | urumqi
# Processing Record 15 of Set 10 | fereydun kenar
# Processing Record 16 of Set 10 | piet retief
# Processing Record 17 of Set 10 | la rioja
# Processing Record 18 of Set 10 | shinpokh
# Processing Record 19 of Set 10 | auki
# Processing Record 20 of Set 10 | wattegama
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | illintsi
# Processing Record 23 of Set 10 | permet
# Processing Record 24 of Set 10 | tiksi
# Processing Record 25 of Set 10 | saint anthony
# Processing Record 26 of Set 10 | ialibu
# Processing Record 27 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 10 | ureki
# Processing Record 29 of Set 10 | thinadhoo
# Processing Record 30 of Set 10 | broken hill
# Processing Record 31 of Set 10 | bahia blanca
# Processing Record 32 of Set 10 | birao
# Processing Record 33 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 10 | lakes entrance
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | cornetu
# Processing Record 37 of Set 10 | burica
# City not found. Skipping...
# Processing Record 38 of Set 10 | ruidoso
# Processing Record 39 of Set 10 | kysyl-syr
# Processing Record 40 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 10 | ewa beach
# Processing Record 42 of Set 10 | makakilo city
# Processing Record 43 of Set 10 | esmeraldas
# Processing Record 44 of Set 10 | chon daen
# Processing Record 45 of Set 10 | morar
# Processing Record 46 of Set 10 | sibolga
# Processing Record 47 of Set 10 | sioux lookout
# Processing Record 48 of Set 10 | buta
# Processing Record 49 of Set 10 | kathmandu
# Processing Record 50 of Set 10 | liwale
# Processing Record 1 of Set 11 | yuncheng
# Processing Record 2 of Set 11 | chama
# Processing Record 3 of Set 11 | harindanga
# Processing Record 4 of Set 11 | san angelo
# Processing Record 5 of Set 11 | ostersund
# Processing Record 6 of Set 11 | tefe
# Processing Record 7 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 11 | barranca
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 11 | roma
# Processing Record 12 of Set 11 | siavonga
# Processing Record 13 of Set 11 | north bend
# Processing Record 14 of Set 11 | mubende
# Processing Record 15 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 11 | haysville
# Processing Record 17 of Set 11 | katherine
# Processing Record 18 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 19 of Set 11 | christchurch
# Processing Record 20 of Set 11 | bangassou
# Processing Record 21 of Set 11 | togur
# Processing Record 22 of Set 11 | waycross
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | rio grande
# Processing Record 25 of Set 11 | sabang
# Processing Record 26 of Set 11 | andenes
# Processing Record 27 of Set 11 | puteyets
# Processing Record 28 of Set 11 | uruzgan
# Processing Record 29 of Set 11 | porto santo
# Processing Record 30 of Set 11 | benito juarez
# Processing Record 31 of Set 11 | banda aceh
# Processing Record 32 of Set 11 | ayagoz
# Processing Record 33 of Set 11 | devils lake
# Processing Record 34 of Set 11 | malangwa
# Processing Record 35 of Set 11 | carndonagh
# Processing Record 36 of Set 11 | vizimyary
# City not found. Skipping...
# Processing Record 37 of Set 11 | novokuznetsk
# Processing Record 38 of Set 11 | chicaman
# Processing Record 39 of Set 11 | adwa
# Processing Record 40 of Set 11 | bereda
# Processing Record 41 of Set 11 | imphal
# Processing Record 42 of Set 11 | kotka
# Processing Record 43 of Set 11 | kortkeros
# Processing Record 44 of Set 11 | mitsamiouli
# Processing Record 45 of Set 11 | ust-maya
# Processing Record 46 of Set 11 | orlik
# Processing Record 47 of Set 11 | koshigaya
# Processing Record 48 of Set 11 | koungheul
# Processing Record 49 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 11 | chissamba
# Processing Record 1 of Set 12 | ketchikan
# Processing Record 2 of Set 12 | griffith
# Processing Record 3 of Set 12 | kargopol
# Processing Record 4 of Set 12 | tombouctou
# Processing Record 5 of Set 12 | healdsburg
# Processing Record 6 of Set 12 | itacare
# Processing Record 7 of Set 12 | ayolas
# Processing Record 8 of Set 12 | biak
# Processing Record 9 of Set 12 | strezhevoy
# Processing Record 10 of Set 12 | surt
# Processing Record 11 of Set 12 | aripuana
# Processing Record 12 of Set 12 | soanierana ivongo
# Processing Record 13 of Set 12 | san quintin
# Processing Record 14 of Set 12 | casablanca
# Processing Record 15 of Set 12 | gravdal
# Processing Record 16 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 17 of Set 12 | port-gentil
# Processing Record 18 of Set 12 | rawson
# Processing Record 19 of Set 12 | mangrol
# Processing Record 20 of Set 12 | angoche
# Processing Record 21 of Set 12 | zelenoborskiy
# Processing Record 22 of Set 12 | moroni
# Processing Record 23 of Set 12 | maputo
# Processing Record 24 of Set 12 | lodja
# Processing Record 25 of Set 12 | shahpur
# Processing Record 26 of Set 12 | miramar
# Processing Record 27 of Set 12 | nagsabaran
# City not found. Skipping...
# Processing Record 28 of Set 12 | kisanga
# Processing Record 29 of Set 12 | beyneu
# Processing Record 30 of Set 12 | poronaysk
# Processing Record 31 of Set 12 | viet tri
# Processing Record 32 of Set 12 | arman
# Processing Record 33 of Set 12 | campbellsville
# Processing Record 34 of Set 12 | altay
# Processing Record 35 of Set 12 | brasileia
# Processing Record 36 of Set 12 | skjervoy
# Processing Record 37 of Set 12 | khawhai
# Processing Record 38 of Set 12 | nakhon phanom
# Processing Record 39 of Set 12 | matara
# Processing Record 40 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 12 | wangdiphodrang
# City not found. Skipping...
# Processing Record 42 of Set 12 | coos bay
# Processing Record 43 of Set 12 | anadyr
# Processing Record 44 of Set 12 | talnakh
# Processing Record 45 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 12 | el tocuyo
# Processing Record 47 of Set 12 | tucurui
# Processing Record 48 of Set 12 | ulety
# Processing Record 49 of Set 12 | penzance
# Processing Record 50 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 13 | zachepylivka
# Processing Record 2 of Set 13 | abha
# Processing Record 3 of Set 13 | svetlogorsk
# Processing Record 4 of Set 13 | westport
# Processing Record 5 of Set 13 | yola
# Processing Record 6 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 13 | nabire
# Processing Record 8 of Set 13 | dakar
# Processing Record 9 of Set 13 | salinas
# Processing Record 10 of Set 13 | mana
# Processing Record 11 of Set 13 | mandera
# Processing Record 12 of Set 13 | sumter
# Processing Record 13 of Set 13 | farafenni
# Processing Record 14 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 13 | vestmanna
# Processing Record 16 of Set 13 | lavrentiya
# Processing Record 17 of Set 13 | salalah
# Processing Record 18 of Set 13 | castelletto sopra ticino
# Processing Record 19 of Set 13 | gharo
# Processing Record 20 of Set 13 | vidisha
# Processing Record 21 of Set 13 | corinto
# Processing Record 22 of Set 13 | kuryk
# Processing Record 23 of Set 13 | bilibino
# Processing Record 24 of Set 13 | tecoanapa
# Processing Record 25 of Set 13 | tornio
# Processing Record 26 of Set 13 | letlhakeng
# Processing Record 27 of Set 13 | puri
# Processing Record 28 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 13 | tigil
# Processing Record 30 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 13 | emerald
# Processing Record 32 of Set 13 | limoges
# Processing Record 33 of Set 13 | banjar
# Processing Record 34 of Set 13 | sitka
# Processing Record 35 of Set 13 | coracora
# Processing Record 36 of Set 13 | gat
# Processing Record 37 of Set 13 | kyle
# Processing Record 38 of Set 13 | bac lieu
# Processing Record 39 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 13 | dulce nombre de culmi
# Processing Record 41 of Set 13 | ginda
# Processing Record 42 of Set 13 | jining
# Processing Record 43 of Set 13 | ngunguru
# Processing Record 44 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 13 | puerto suarez
# Processing Record 46 of Set 13 | champerico
# Processing Record 47 of Set 13 | tucuma
# Processing Record 48 of Set 13 | puiesti
# Processing Record 49 of Set 13 | ransang
# Processing Record 50 of Set 13 | quelimane
# Processing Record 1 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 14 | qaqortoq
# Processing Record 3 of Set 14 | naron
# Processing Record 4 of Set 14 | laramie
# Processing Record 5 of Set 14 | tatawin
# Processing Record 6 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 14 | sokoni
# Processing Record 8 of Set 14 | benbrook
# Processing Record 9 of Set 14 | ibb
# Processing Record 10 of Set 14 | zheleznodorozhnyy
# Processing Record 11 of Set 14 | mount darwin
# Processing Record 12 of Set 14 | igunga
# Processing Record 13 of Set 14 | dalaba
# Processing Record 14 of Set 14 | machali
# Processing Record 15 of Set 14 | tiruchchendur
# Processing Record 16 of Set 14 | bull savanna
# Processing Record 17 of Set 14 | chifeng
# Processing Record 18 of Set 14 | camana
# Processing Record 19 of Set 14 | alice town
# Processing Record 20 of Set 14 | chapais
# Processing Record 21 of Set 14 | solnechnyy
# Processing Record 22 of Set 14 | deputatskiy
# Processing Record 23 of Set 14 | greifswald
# Processing Record 24 of Set 14 | huarmey
# Processing Record 25 of Set 14 | lobatse
# Processing Record 26 of Set 14 | binzhou
# Processing Record 27 of Set 14 | pangkalanbuun
# Processing Record 28 of Set 14 | sola
# Processing Record 29 of Set 14 | baghdad
# Processing Record 30 of Set 14 | killybegs
# Processing Record 31 of Set 14 | vanimo
# Processing Record 32 of Set 14 | palmas
# Processing Record 33 of Set 14 | lompoc
# Processing Record 34 of Set 14 | kattivakkam
# Processing Record 35 of Set 14 | miri
# Processing Record 36 of Set 14 | nieuw amsterdam
# Processing Record 37 of Set 14 | tabuk
# Processing Record 38 of Set 14 | mae sot
# Processing Record 39 of Set 14 | kamina
# Processing Record 40 of Set 14 | usogorsk
# Processing Record 41 of Set 14 | aykhal
# Processing Record 42 of Set 14 | tatarani
# Processing Record 43 of Set 14 | yoichi
# Processing Record 44 of Set 14 | sao jose da coroa grande
# Processing Record 45 of Set 14 | kolyvan
# Processing Record 46 of Set 14 | benguela
# Processing Record 47 of Set 14 | fasa
# Processing Record 48 of Set 14 | brownsville
# Processing Record 49 of Set 14 | praia
# Processing Record 50 of Set 14 | batsfjord
# Processing Record 1 of Set 15 | maanshan
# Processing Record 2 of Set 15 | dhemaji
# Processing Record 3 of Set 15 | saint simons
# Processing Record 4 of Set 15 | omutinskoye
# City not found. Skipping...
# Processing Record 5 of Set 15 | fethiye
# Processing Record 6 of Set 15 | svetlograd
# Processing Record 7 of Set 15 | valdosta
# Processing Record 8 of Set 15 | macduff
# Processing Record 9 of Set 15 | teya
# Processing Record 10 of Set 15 | port-cartier
# Processing Record 11 of Set 15 | ixtapa
# Processing Record 12 of Set 15 | gusau
# Processing Record 13 of Set 15 | grand-lahou
# Processing Record 14 of Set 15 | flin flon
# Processing Record 15 of Set 15 | aksarka
# Processing Record 16 of Set 15 | yebaishou
# Processing Record 17 of Set 15 | benalla
# Processing Record 18 of Set 15 | zlobin
# Processing Record 19 of Set 15 | oranjestad
# Processing Record 20 of Set 15 | northam
# Processing Record 21 of Set 15 | egvekinot
# Processing Record 22 of Set 15 | magnolia
# Processing Record 23 of Set 15 | gharghoda
# Processing Record 24 of Set 15 | teguise
# Processing Record 25 of Set 15 | college
# Processing Record 26 of Set 15 | ishikari
# Processing Record 27 of Set 15 | el rosario
# Processing Record 28 of Set 15 | yermakovskoye
# Processing Record 29 of Set 15 | nioro
# Processing Record 30 of Set 15 | obo
# Processing Record 31 of Set 15 | tongliao
# Processing Record 32 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 15 | arona
# Processing Record 34 of Set 15 | lodingen
# Processing Record 35 of Set 15 | kolondieba
# Processing Record 36 of Set 15 | duz
# City not found. Skipping...
# Processing Record 37 of Set 15 | poreba
# Processing Record 38 of Set 15 | xiongyue
# Processing Record 39 of Set 15 | batuan
# Processing Record 40 of Set 15 | oranjemund
# Processing Record 41 of Set 15 | krasyliv
# Processing Record 42 of Set 15 | corpus christi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nicoya      Cr  10.1483  -85.4520     84.13        67          98
# 1     Vaini      To -21.2000 -175.2000     75.36        78          40
# 2  Antalaha      Mg -14.9003   50.2788     70.18        81          52
# 3     Kapaa      Us  22.0752 -159.3190     81.12        86          40
# 4    Juneau      Us  58.3019 -134.4197     63.84        66          75
#
#    Wind Speed               Weather
# 0        5.91       overcast clouds
# 1        6.91      scattered clouds
# 2        7.63         broken clouds
# 3       12.66      scattered clouds
# 4        8.05  heavy intensity rain

# %%
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
